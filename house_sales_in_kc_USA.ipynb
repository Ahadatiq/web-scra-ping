# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\HP\Documents\Kc_housing_dataset_USA.csv")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df = df.drop_duplicates()
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
import math
df['bathrooms'] = df['bathrooms'].apply(math.floor)
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3          1
# 1      6414100192  20141209T000000  538000.0         3          2
# 2      5631500400  20150225T000000  180000.0         2          1
# 3      2487200875  20141209T000000  604000.0         4          3
# 4      1954400510  20150218T000000  510000.0         3          2
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3          2
# 21609  6600060120  20150223T000000  400000.0         4          2
# 21610  1523300141  20140623T000000  402101.0         2          0
# 21611   291310100  20150116T000000  400000.0         3          2
# 21612  1523300157  20141015T000000  325000.0         2          0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df= df.fillna('')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3          1
# 1      6414100192  20141209T000000  538000.0         3          2
# 2      5631500400  20150225T000000  180000.0         2          1
# 3      2487200875  20141209T000000  604000.0         4          3
# 4      1954400510  20150218T000000  510000.0         3          2
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3          2
# 21609  6600060120  20150223T000000  400000.0         4          2
# 21610  1523300141  20140623T000000  402101.0         2          0
# 21611   291310100  20150116T000000  400000.0         3          2
# 21612  1523300157  20141015T000000  325000.0         2          0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn theme
sns.set_theme(style="whitegrid")

# Visualization 1: Price Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True, bins=50, color="blue")
plt.title("Distribution of House Prices", fontsize=16)
plt.xlabel("Price ($)", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['sqft_living'], y=df['price'], alpha=0.5)
plt.title("Price vs. Square Footage of Living Space", fontsize=16)
plt.xlabel("Living Space (sqft)", fontsize=12)
plt.ylabel("Price ($)", fontsize=12)
plt.show()

# %%
# Visualization 3: Price vs. Number of Bedrooms
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['bedrooms'], y=df['price'])
plt.title("Price Variation Across Number of Bedrooms", fontsize=16)
plt.xlabel("Number of Bedrooms", fontsize=12)
plt.ylabel("Price ($)", fontsize=12)
plt.yscale('log')  # Use log scale for better visualization
plt.show()

# %%
# Visualization 4: Geographic Visualization of Prices
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['long'], y=df['lat'], 
                hue=df['price'], palette="viridis", alpha=0.6)
plt.title("Geographic Distribution of House Prices", fontsize=16)
plt.xlabel("Longitude", fontsize=12)
plt.ylabel("Latitude", fontsize=12)
plt.show()

# %%
# Visualization 5: Renovation Effect on Prices
plt.figure(figsize=(10, 6))
df['renovated'] = df['yr_renovated'].apply(lambda x: 'Yes' if x > 0 else 'No')
sns.boxplot(x='renovated', y='price', data=df)
plt.title("Effect of Renovation on House Prices", fontsize=16)
plt.xlabel("Renovated", fontsize=12)
plt.ylabel("Price ($)", fontsize=12)
plt.yscale('log')  # Use log scale for better visualization
plt.show()

# %%
floor_value_counts = df['floors'].value_counts()
floor_value_counts
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
sns.regplot(x='sqft_above',y='price',data=df)
plt.xlabel('sqft_above')
plt.ylabel('price')
plt.title('regplot of price with sqft_above')
plt.show()

# %%
import sklearn
from sklearn.linear_model import LinearRegression
import numpy as np

# Assuming 'df' is a pandas DataFrame
X = df[['sqft_living']]  # Reshape to 2D array
Y = df['price']

lr = LinearRegression()
lr.fit(X, Y)

# Print the R-squared score
print(lr.score(X, Y))
# Out:
# 0.49286538652201417

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\HP\Documents\Kc_housing_dataset_USA.csv")
features =df[["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]]     
Y = df['price']
lr = LinearRegression()
lr = lr.fit(features,Y)
print(lr.score(features,Y))
# Out:
# 0.657697786636558

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# Load the dataset
df = pd.read_csv(r"C:\Users\HP\Documents\Kc_housing_dataset_USA.csv")

# Define the feature columns
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", "view",
            "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df[features]  # Extract the features from the DataFrame
Y = df['price']   # Extract the target variable (price)

# Define the pipeline steps
steps = [
    ('scale', StandardScaler()),
    ('polynomial', PolynomialFeatures(include_bias=False)),
    ('model', LinearRegression())
]

# Create the pipeline
pipe = Pipeline(steps)

# Fit the pipeline to the data
pipe.fit(X, Y)

# Make predictions
ypipe = pipe.predict(X)

# Print the R-squared score of the model
print(pipe.score(X, Y))
# Out:
# 0.7495918058006221

# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# Load the dataset
df = pd.read_csv(r"C:\Users\HP\Documents\Kc_housing_dataset_USA.csv")

# Define the feature columns
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", "view",
            "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]

# Extract features and target variable
x = df[features]
y = df['price']

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Create and train the Ridge regression model
RidgeModel = Ridge(alpha=0.1)
RidgeModel.fit(x_train, y_train)

# Make predictions on the test set
yhat = RidgeModel.predict(x_test)

# Calculate and print the R-squared score
print(r2_score(y_test, yhat))
# Out:
# 0.6449342671529874
